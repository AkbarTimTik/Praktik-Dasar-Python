# %%
a = 1
b = 0.125
c = 1.12 
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'float'>

# %%
s1 = 3 + 2j
print(type(s1))
print(s1.real)
print(s1.imag)
j = int(1)
s2 = float(2.5+j)
print(s2)
# Out:
# <class 'complex'>
# 3.0
# 2.0
# 3.5

# %%
import math
a1 = 12
a2 = 6
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b) #pembagian bilangan bulat
print(a%b) #modulus
print(a**b) #eksponen
print(math.sqrt (49))
print(math.pi*5)
print(math.cos(45))
# Out:
# 1.125
# 0.875
# 0.125
# 8.0
# 8.0
# 0.0
# 1.0
# 7.0
# 15.707963267948966
# 0.5253219888177297

# %%
t = True
f = False
print(t and f)
print(f and f)
print(t and t)
# Out:
# False
# False
# True
